# %%
#Importing Core Modules
import pandas as pd
import numpy as np


#Importing Visualization Modules
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Loading the data in a dataframe
df = pd.read_csv('./data/train.csv')

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df['Street'].value_counts()
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Dropping the Id column
df = df.drop('Id'  ,axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
#Listing the numerical attribute and getting a better view of the attributes by usig the transpose method 
df.select_dtypes(exclude=['object']).describe().round(decimals=2).transpose()
# Out:
#                 count       mean       std      min        25%       50%  \
# MSSubClass     1460.0      56.90     42.30     20.0      20.00      50.0
# LotFrontage    1201.0      70.05     24.28     21.0      59.00      69.0
# LotArea        1460.0   10516.83   9981.26   1300.0    7553.50    9478.5
# OverallQual    1460.0       6.10      1.38      1.0       5.00       6.0
# OverallCond    1460.0       5.58      1.11      1.0       5.00       5.0
# YearBuilt      1460.0    1971.27     30.20   1872.0    1954.00    1973.0
# YearRemodAdd   1460.0    1984.87     20.65   1950.0    1967.00    1994.0
# MasVnrArea     1452.0     103.69    181.07      0.0       0.00       0.0
# BsmtFinSF1     1460.0     443.64    456.10      0.0       0.00     383.5
# BsmtFinSF2     1460.0      46.55    161.32      0.0       0.00       0.0
# BsmtUnfSF      1460.0     567.24    441.87      0.0     223.00     477.5
# TotalBsmtSF    1460.0    1057.43    438.71      0.0     795.75     991.5
# ...

# %%
# Listing the attributes with object data type
df.select_dtypes(include=['object']).columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
#Getting the summary of categorical attributes
df.select_dtypes(include=['object']).describe().transpose()
# Out:
#               count unique      top  freq
# MSZoning       1460      5       RL  1151
# Street         1460      2     Pave  1454
# Alley            91      2     Grvl    50
# LotShape       1460      4      Reg   925
# LandContour    1460      4      Lvl  1311
# Utilities      1460      2   AllPub  1459
# LotConfig      1460      5   Inside  1052
# LandSlope      1460      3      Gtl  1382
# Neighborhood   1460     25    NAmes   225
# Condition1     1460      9     Norm  1260
# Condition2     1460      8     Norm  1445
# BldgType       1460      5     1Fam  1220
# HouseStyle     1460      8   1Story   726
# RoofStyle      1460      6    Gable  1141
# RoofMatl       1460      8  CompShg  1434
# Exterior1st    1460     15  VinylSd   515
# Exterior2nd    1460     16  VinylSd   504
# MasVnrType     1452      4     None   864
# ExterQual      1460      4       TA   906
# ExterCond      1460      5       TA  1282
# Foundation     1460      6    PConc   647
# ...

# %%
#Looking at the statistical summary of our target variable
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# Getting the distribution plot of the target varible
sns.displot(df['SalePrice'])

# %%
# Taking the log to make the distribution more normal
sns.displot(np.log(df['SalePrice']))
plt.title('Distribution of the Log transformed SalePrice')
plt.xlabel('log(saleprice)')
plt.show()

# %%
# Copying the numerical attributes to a new variable
num_attributes = df.select_dtypes(exclude='object').drop(['SalePrice'], axis=1).copy()

# %%
# Printing the number of numerical attributes to check if the copying done in  the previous cell is done correctly
print(len(num_attributes.columns))
# Out:
# 36

# %%
# Writing a loop to plot all the numerical attributes copied in the num_attr variable
fig = plt.figure(figsize=(12,18))



print(len(num_attributes.columns))

fig = plt.figure(figsize=(12,18))
for i in range(len(num_attributes.columns)):
    fig.add_subplot(9,4,i+1)
    sns.histplot( data = num_attributes.iloc[:,i].dropna(), )
    plt.xlabel(num_attributes.columns[i])

plt.tight_layout()
plt.show()
# Out:
# 36

# %%
# Writing a loop to create boxplots  of all the numeric attributes

fig = plt.figure(figsize=(10,15))

for i in range(len(num_attributes.columns)):
    fig.add_subplot(9,4,i+1)
    sns.boxplot(y=num_attributes.iloc[:,i])
    
plt.tight_layout()
plt.show()

# %%
df.plot(kind="scatter", x="OverallQual", y="YearBuilt",  s=df["GrLivArea"], label="GrLivArea", 
             alpha=0.3, figsize=(10,7), c="SalePrice", cmap=plt.get_cmap("jet"), colorbar=True)

plt.legend()

# %%
# Correlation between various numerical value
corr = df.corr()

#Using mask to get triangular correlation matrix
ax = plt.subplots(figsize=(15,15))
mask = np.zeros_like(corr ,dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr, mask=mask,cmap=sns.diverging_palette(220,10,as_cmap=True), square=True,  vmin=-1, vmax=1, linewidth=.5)
# Out:
# C:\Users\Binod\AppData\Local\Temp\ipykernel_2040\4012608414.py:6: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr ,dtype = np.bool)
# <AxesSubplot:>

# %%
# Checking the correlation of all the numerical attributes with SalePrice
corr['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# ...

# %%
# Creating pairplots of the highly correlated values
col = ['SalePrice' , 'OverallQual' , 'YearBuilt' , 'GrLivArea']
sns.pairplot(df[col])

# %%
# Creating a barpot to further clarify the correlation between OverallQual and the target variable
sns.barplot(df.OverallQual , df.SalePrice)
# Out:
# C:\Users\Binod\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
# Creating a boxplot for the visualization of the correlation between OverallQual and the target variable
plt.figure(figsize=(18,8))
sns.boxplot(x=df.OverallQual , y=df.SalePrice)
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
# Visualizing the correlation between the age of the house and it's price
var = 'YearBuilt'
data = pd.concat([df['SalePrice'], df[var]], axis=1)
ax = plt.subplots(figsize=(16,8))
fig = sns.boxplot(x=var, y='SalePrice', data=data)
fig.axis(ymin=0, ymax=800000)
plt.xticks(rotation=90)
fig
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %%
# Only important correlations and not auto-correlations
threshold = 0.5
important_corrs = (corr[abs(corr) > threshold][corr != 1.0]) \
    .unstack().dropna().to_dict()

unique_important_corrs = pd.DataFrame(
    list(set([(tuple(sorted(key)), important_corrs[key]) \
    for key in important_corrs])), columns=['attribute pair', 'correlation'])

# Sorted by absolute value
unique_important_corrs = unique_important_corrs.iloc[
    abs(unique_important_corrs['correlation']).argsort()[::-1]]

unique_important_corrs
# Out:
#                   attribute pair  correlation
# 33      (GarageArea, GarageCars)     0.882475
# 36      (GarageYrBlt, YearBuilt)     0.825667
# 3      (GrLivArea, TotRmsAbvGrd)     0.825489
# 19       (1stFlrSF, TotalBsmtSF)     0.819530
# 24      (OverallQual, SalePrice)     0.790982
# 11        (GrLivArea, SalePrice)     0.708624
# 35         (2ndFlrSF, GrLivArea)     0.687501
# 26  (BedroomAbvGr, TotRmsAbvGrd)     0.676620
# 32    (BsmtFinSF1, BsmtFullBath)     0.649212
# 13   (GarageYrBlt, YearRemodAdd)     0.642277
# 7        (GarageCars, SalePrice)     0.640409
# 18         (FullBath, GrLivArea)     0.630012
# 34       (GarageArea, SalePrice)     0.623431
# 6       (2ndFlrSF, TotRmsAbvGrd)     0.616423
# 9       (SalePrice, TotalBsmtSF)     0.613581
# 4           (2ndFlrSF, HalfBath)     0.609707
# 20         (1stFlrSF, SalePrice)     0.605852
# 2      (GarageCars, OverallQual)     0.600671
# 37      (GrLivArea, OverallQual)     0.593007
# ...

# %%
cat_columns = df.select_dtypes(include='object').columns
print(cat_columns)
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
var = df['KitchenQual']
ax = plt.subplots(figsize=(10,6))
sns.boxplot(y=df.SalePrice , x=var)
plt.show()

# %%
ax = plt.subplots(figsize=(12,8))
sns.boxplot(y=df.SalePrice , x=df.HouseStyle)
plt.xticks(rotation=40)
plt.show()

# %%
# Counting the frequency of different house types present in the dataframe
fig = plt.figure(figsize=(12,4))
sns.countplot(x='HouseStyle',data=df)
plt.xticks(rotation=90)
plt.ylabel('Frequency')
plt.show()

# %%
df['HouseStyle'].value_counts()
# Out:
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64

# %%
plt.scatter(df['YearBuilt'],df['HouseStyle'])

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC         1453
# MiscFeature    1406
# Alley          1369
# Fence          1179
# FireplaceQu     690
#                ...
# Heating           0
# HeatingQC         0
# MSZoning          0
# 1stFlrSF          0
# SalePrice         0
# Length: 80, dtype: int64

# %%
#Imputing Misiing Values
df_processed = df

#Categorical Columns
cat_cols_fill_none = ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
                     'GarageCond', 'GarageQual', 'GarageFinish', 'GarageType',
                     'BsmtFinType2', 'BsmtExposure', 'BsmtFinType1', 'BsmtQual', 'BsmtCond',
                     'MasVnrType']

#Replacing the missing values in the catgorical columns with None
for cat in cat_cols_fill_none:
    df_processed[cat] = df_processed[cat].fillna('None')
    
#Grouping by neighbourhood and filling the missing values of LotFrontage on the basis ofthe median LotForntage of the neighbourhood
df_processed['LotFrontage'] = df_processed.groupby('Neighborhood')['LotFrontage'].transform( lambda x:x.fillna(x.median()))

# Garage: GarageYrBlt, GarageArea and GarageCars these are numerical columns, replace with zero
for col in ['GarageYrBlt', 'GarageArea', 'GarageCars']:
    df_processed[col] = df_processed[col].fillna(int(0))
    
# MasVnrArea replace with zero
df_processed['MasVnrArea'] = df_processed['MasVnrArea'].fillna(int(0))

#Using the mode value to fiil in the missing values in the Electrical column
df_processed['Electrical'] = df_processed['Electrical'].fillna(df_processed['Electrical'].mode())[0]

# There is no use of the Utilities column so dropping it from the dataframe
df_processed = df_processed.drop(['Utilities'] , axis=1)

# Getting the count to assure that there are no missing values in the dataframe
df_processed.isnull().apply(sum).max()
# Out:
# 0

# %%
# Removing the noisy data
num_attributes = df_processed.select_dtypes(exclude='object')
high_quant = df_processed.quantile(.999)

for i in num_attributes.columns:
    df_processed = df_processed.drop(df_processed[i][df_processed[i]>high_quant[i]].index)
df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 0 to 1458
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1422 non-null   int64
#  1   MSZoning       1422 non-null   object
#  2   LotFrontage    1422 non-null   float64
#  3   LotArea        1422 non-null   int64
#  4   Street         1422 non-null   object
#  5   Alley          1422 non-null   object
#  6   LotShape       1422 non-null   object
#  7   LandContour    1422 non-null   object
#  8   LotConfig      1422 non-null   object
#  9   LandSlope      1422 non-null   object
#  10  Neighborhood   1422 non-null   object
#  11  Condition1     1422 non-null   object
#  12  Condition2     1422 non-null   object
#  13  BldgType       1422 non-null   object
#  14  HouseStyle     1422 non-null   object
#  15  OverallQual    1422 non-null   int64
#  16  OverallCond    1422 non-null   int64
# ...

# %%
###Remove highly correlated features
#Remove the attributes identified for removing while viewing scatterplots and corr values
attributes_drop = ['MiscVal', 'MoSold', 'YrSold', 'BsmtFinSF2','BsmtHalfBath','MSSubClass',
                   'GarageArea', 'GarageYrBlt', '3SsnPorch']
df_processed = df_processed.drop(attributes_drop , axis=1)

# %%
#Transforming categorical attributes
from sklearn.preprocessing import OneHotEncoder
cat_encoder = OneHotEncoder()
df_processed_1hot = cat_encoder.fit_transform(df_processed)
df_processed_1hot
# Out:
# <1422x7333 sparse matrix of type '<class 'numpy.float64'>'
# 	with 99540 stored elements in Compressed Sparse Row format>

# %%
# Importing the pipeline modules
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

#Separating the features and the target variable
df_X = df_processed.drop('SalePrice' ,axis=1)
df_Y = df['SalePrice'].copy()

# Get the list of numerical and categorical attributes separately
num_attribs = list(df_X.select_dtypes(exclude='object'))
cat_attribs = list(df_X.select_dtypes(include='object'))

# Numerical Pipeline to impute any missing values with median and scale attributes
num_pipeline = Pipeline([('imputer',SimpleImputer(strategy= 'median')) , ('std_scaler', StandardScaler())])

# %%
# Building a single transformer to transform both numerical and categorical data
full_pipeline = ColumnTransformer([('num',num_pipeline,num_attribs),('cat',OneHotEncoder(),cat_attribs)])

#Description before applying transforms
print(df_Y.describe())

#Applying log transformation to SalePrice
df_Y_prepared =np.log(df_Y)

#Run the transformation pipeline on all other attributes
df_X_prepared = full_pipeline.fit_transform(df_X)

#Description before applying transforms
print(df_Y_prepared.describe())

df_X_prepared
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# count    1460.000000
# mean       12.024051
# std         0.399452
# min        10.460242
# 25%        11.775097
# 50%        12.001505
# 75%        12.273731
# max        13.534473
# Name: SalePrice, dtype: float64
# <1422x281 sparse matrix of type '<class 'numpy.float64'>'
# 	with 98118 stored elements in Compressed Sparse Row format>
